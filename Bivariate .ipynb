# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.cov()
# Out:
#                   sl_no         ssc_p         hsc_p      degree_p  \
# sl_no       3870.000000    -52.641355    -58.106028    -40.413645
# ssc_p        -52.641355    117.228377     60.348373     42.897137
# hsc_p        -58.106028     60.348373    118.755706     34.819820
# degree_p     -40.413645     42.897137     34.819820     54.151103
# etest_p       52.556168     37.659225     35.461678     21.929469
# mba_p          8.102336     24.535952     22.555846     17.272020
# salary    361617.668689  28777.386468  66977.716032 -11739.948520
#
#                 etest_p         mba_p        salary
# sl_no         52.556168      8.102336  3.616177e+05
# ssc_p         37.659225     24.535952  2.877739e+04
# hsc_p         35.461678     22.555846  6.697772e+04
# degree_p      21.929469     17.272020 -1.173995e+04
# etest_p      176.251018     16.886973  2.287876e+05
# mba_p         16.886973     34.028376  9.624979e+04
# salary    228787.619507  96249.789024  8.734295e+09

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# 0       No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1      Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2       No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3       No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4       No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..     ...      ...            ...    ...         ...       ...
# 210     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(dataset[["etest_p","salary"]])
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14984\4272701912.py in <module>
# ----> 1 calc_vif(dataset[["etest_p","salary"]])
#       2 df = df.dropna()
#
# ~\AppData\Local\Temp\ipykernel_14984\2314162687.py in calc_vif(X)
#       6     vif = pd.DataFrame()
#       7     vif["variables"] = X.columns
# ----> 8     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#       9
#      10     return(vif)
#
# ~\AppData\Local\Temp\ipykernel_14984\2314162687.py in <listcomp>(.0)
#       6     vif = pd.DataFrame()
#       7     vif["variables"] = X.columns
# ----> 8     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#       9
#      10     return(vif)
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     192     mask = np.arange(k_vars) != exog_idx
#     193     x_noti = exog[:, mask]
# --> 194     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     195     vif = 1. / (1. - r_squared_i)
#     196     return vif
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     905             warnings.warn(msg, ValueWarning)
#     906         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 907                                   hasconst=hasconst, **kwargs)
#     908         if "weights" in self._init_keys:
#     909             self._init_keys.remove("weights")
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     732             weights = weights.squeeze()
#     733         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 734                                   weights=weights, hasconst=hasconst, **kwargs)
#     735         nobs = self.exog.shape[0]
#     736         weights = self.weights
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     192
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     265
#     266     def __init__(self, endog, exog=None, **kwargs):
# --> 267         super().__init__(endog, exog, **kwargs)
#     268         self.initialize()
#     269
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      91         hasconst = kwargs.pop('hasconst', None)
#      92         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 93                                       **kwargs)
#      94         self.k_constant = self.data.k_constant
#      95         self.exog = self.data.exog
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     130
#     131     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133         # kwargs arrays could have changed, easier to just attach here
#     134         for key in kwargs:
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     699     klass = handle_data_class_factory(endog, exog)
#     700     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 701                  **kwargs)
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      86         self.const_idx = None
#      87         self.k_constant = 0
# ---> 88         self._handle_constant(hasconst)
#      89         self._check_integrity()
#      90         self._cache = {}
#
# C:\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     132             exog_max = np.max(self.exog, axis=0)
#     133             if not np.isfinite(exog_max).all():
# --> 134                 raise MissingDataError('exog contains inf or nans')
#     135             exog_min = np.min(self.exog, axis=0)
#     136             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# #### Independant Sample- Unpaired T Test
# Diferrent Group(Male, Female) but same contion(salary)

# %%
dataset[dataset['gender']=='F']["salary"]
# Out:
# 6           0.0
# 12          0.0
# 13     218000.0
# 15     200000.0
# 17          0.0
#          ...
# 197    260000.0
# 198         0.0
# 204    210000.0
# 208         0.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
#print(male)
ttest_ind(male, female)
# Out:
# Ttest_indResult(statistic=2.0937842507001165, pvalue=0.03746230397067219)

# %% [markdown]
# #### Dependant Sample-Paired T_Test
# Same Group(Male) but Different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male, male1)
# Out:
# Ttest_relResult(statistic=0.6842940392688153, pvalue=0.4949370716000775)

# %%
# Hypothesis Testing

# %%
#Statement: Test whether SSC_p of male and HSC_P of Male is Same?

# %%
#Null hypothesis=There is no similarity between 10th pass mark of male  and 12th pass mark of male

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male, male1)
# Out:
# Ttest_relResult(statistic=0.6842940392688153, pvalue=0.4949370716000775)

# %% [markdown]
# # Reject Null hypothesis p<0.05
# # Accept Null Hypothesi and Reject Alternate hypothsis

# %% [markdown]
# # ANAVO : Analysis of Variance

# %%
import scipy.stats as stats

stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.49895574725815317)
